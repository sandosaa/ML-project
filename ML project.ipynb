# %% [markdown]
# <h1 style="color:#900030; font-size:45px; text-align:center; font-weight:bold;">
# Student Stress Factors Analysis & Classification
# </h1>

# %% [markdown]
# <div style="text-align:center;">
#     <img src="dataset-cover.jpg" width="10000">
# </div>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:25px; text-align:center; font-weight:bold;text-align:left;">
#  Why we focused on Student Stress Factors?
# </h1>

# %% [markdown]
#  <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
#
#  We chose this type of topic because it is one of the needs that affect us at the present time, how much pressure we are going through has begun to affect our lives, so analyzing these factors will let us know how we can deal with these pressures and what kind of problems we can avoid.
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:25px; text-align:center; font-weight:bold;text-align:left;">
# 🎀PROJECT GOAL:
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
#
# Using machine Learning Classification Algorithm to build a model that predicts students' stress levels based on a variety of factors.
#
# The model helps identify the causes of stress early, understand the most influential factors, and therefore support students, improve
#
# their mental well-being, and help them better manage their time and studies.
# </h1>
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:25px; text-align:center; font-weight:bold;text-align:left;">
# About Dataset ⬇:
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:15px; text-align:center; font-weight:bold;text-align:left;">
# Description:
# </h1>
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# This dataset provides insights into the different factors affecting student stress levels.
#
# It contains around 20 scientifically selected features across five main categories:
# | Factor               | Features                                                    |
# |----------------------|-------------------------------------------------------------|
# | Psychological        | anxiety_level, self_esteem, mental_health_history, depression |
# | Physiological        | headache, blood_pressure, sleep_quality, breathing_problem |
# | Environmental        | noise_level, living_conditions, safety, basic_needs       |
# | Academic             | academic_performance, study_load, teacher_student_relationship, future_career_concerns |
# | Social               | social_support, peer_pressure, extracurricular_activities, bullying |
#
# </h1>
# <h1 style="color:#D3D3D3; font-size:15px; text-align:center; font-weight:bold;text-align:left;">
#
# The dataset helps in exploring patterns, identifying high-impact stress drivers, and understanding how real-life factors contribute to student stress.
# </h1>
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:25px; text-align:center; font-weight:bold;text-align:left;">
# 🌟PROJECT OBJECTIVE:
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# The main objective of this project is to build a Classification model that predicts students' stress levels
#
# based on these factors.
# The model aims to:
#
# -Identify key stress causes early
#
# -Understand the most influential factors on student stress
#
# -Support students in managing stress
#
# -Improve students' mental well-being and academic performance
#
# -Provide actionable insights to help students better manage their time, health, and social interactions
# </h1>

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:25px; font-weight:bold; text-align:left;">
# Let's Start to Prepare Our Data:
# </h1>
#
# <h2 style="color:#A0A0A0; font-size:15px; font-weight:bold; text-align:left; font-style:italic;">
# Following 2 steps
# </h2>
#
#
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#
#
# -> CLEANING
#
# -> PREPROCESSING
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# <span style="color:#800000;">1-</span> Cleaning Data
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  1-Import Required Libraries
#
# </h1>

# %%
# cspell:disable
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from sklearn.decomposition import PCA
from sklearn.feature_selection import f_classif
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from matplotlib.colors import LinearSegmentedColormap

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  2-Load Our Data
#
# </h1>

# %%
#cspell:disable
data = pd.read_csv(r"StressLevelDataset.csv")
print ("\nDisplay The first 10 rows :") 
data.head(10)
# Out:
# Display The first 10 rows :
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
# 5             20           13                      1          21         3
# 6              4           26                      0           6         1
# 7             17            3                      1          22         4
# 8             13           22                      1          12         3
# 9              6            8                      0          27         4
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# ...

# %%
data.shape
# Out:
# (1100, 21)

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  3-Some Information about our Data
#
# </h1>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
data.describe().T
# Out:
#                                count       mean       std  min   25%   50%  \
# anxiety_level                 1100.0  11.063636  6.117558  0.0   6.0  11.0
# self_esteem                   1100.0  17.777273  8.944599  0.0  11.0  19.0
# mental_health_history         1100.0   0.492727  0.500175  0.0   0.0   0.0
# depression                    1100.0  12.555455  7.727008  0.0   6.0  12.0
# headache                      1100.0   2.508182  1.409356  0.0   1.0   3.0
# blood_pressure                1100.0   2.181818  0.833575  1.0   1.0   2.0
# sleep_quality                 1100.0   2.660000  1.548383  0.0   1.0   2.5
# breathing_problem             1100.0   2.753636  1.400713  0.0   2.0   3.0
# noise_level                   1100.0   2.649091  1.328127  0.0   2.0   3.0
# living_conditions             1100.0   2.518182  1.119208  0.0   2.0   2.0
# safety                        1100.0   2.737273  1.406171  0.0   2.0   2.0
# ...

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  4-Checking & Understanding Our Data
#
# </h1>

# %%
data.isnull().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  0
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.dtypes
# Out:
# anxiety_level                   int64
# self_esteem                     int64
# mental_health_history           int64
# depression                      int64
# headache                        int64
# blood_pressure                  int64
# sleep_quality                   int64
# breathing_problem               int64
# noise_level                     int64
# living_conditions               int64
# safety                          int64
# basic_needs                     int64
# academic_performance            int64
# study_load                      int64
# teacher_student_relationship    int64
# future_career_concerns          int64
# social_support                  int64
# peer_pressure                   int64
# extracurricular_activities      int64
# bullying                        int64
# stress_level                    int64
# dtype: object

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#
#
# 🔘Based on the previous output, there are no missing values or duplicates
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  5-Handling Outliers
#  </h1>
#  -> Calculate the IQR for each numerical column and identify outliers using the 1.5*IQR rule.
#
#
#
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  Outliers Before Cleaning
#
# </h1>

# %%
# cspell:disable
numeric_cols = data.columns
plt.figure(figsize=(20,5))
plt.boxplot(data[numeric_cols].values, tick_labels=numeric_cols, vert=True ,patch_artist=True, boxprops=dict(facecolor='#8C1818'))
plt.title("Outliers Before Cleaning")
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
numeric_cols = data.select_dtypes(include=np.number).columns

# 1-Count Outliers Before Replacement
Q1 = data[numeric_cols].quantile(0.25)
Q3 = data[numeric_cols].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outlier_counts_before = {}
outlier_counts_after = {}

for col in numeric_cols:
    outlier_count_before = data[(data[col] < lower_bound[col]) | (data[col] > upper_bound[col])].shape[0]
    outlier_counts_before[col] = outlier_count_before

    data[col] = np.where((data[col] < lower_bound[col]) | (data[col] > upper_bound[col]), data[col].median(), data[col])

    outlier_count_after = data[(data[col] < lower_bound[col]) | (data[col] > upper_bound[col])].shape[0]
    outlier_counts_after[col] = outlier_count_after

# 4- Combine in DataFrame 
outlier_summary = pd.DataFrame({
    "Outliers Before": outlier_counts_before,
    "Outliers After": outlier_counts_after
})

outlier_summary
# Out:
#                               Outliers Before  Outliers After
# anxiety_level                               0               0
# self_esteem                                 0               0
# mental_health_history                       0               0
# depression                                  0               0
# headache                                    0               0
# blood_pressure                              0               0
# sleep_quality                               0               0
# breathing_problem                           0               0
# noise_level                               173               0
# living_conditions                          62               0
# safety                                      0               0
# basic_needs                                 0               0
# academic_performance                        0               0
# study_load                                165               0
# ...

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Outliers After Cleaning
#
# </h1>

# %%
#cspell:disable
numeric_cols = data.columns
plt.figure(figsize=(20,5))
plt.boxplot(data[numeric_cols].values, tick_labels=numeric_cols, vert=True  ,patch_artist=True, boxprops=dict(facecolor='#8C1818'))
plt.title("Outliers After Cleaning")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Outliers Count Before vs After Cleaning
#
# </h1>

# %%
#cspell:disable
plt.figure(figsize=(20,5))
plt.plot(outlier_summary["Outliers Before"], marker="o", color= '#8C1818')
plt.plot(outlier_summary["Outliers After"], marker="o", color= "#DB0000")
plt.xticks(range(len(numeric_cols)), numeric_cols, rotation=45, ha='right')
plt.title("Outliers Count Before vs After Cleaning")
plt.legend(["Before", "After"])
plt.show()

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# 6- Finally Saving our Cleaning Data
#
# </h1>

# %%
data.to_csv("Cleaned_data.csv" , index = False)

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# <span style="color:#800000;">2-</span> Preprocessing
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# Right now, we are in the process of preparing the model so that we can then use and test the algorithms properly. At this stage, we will perform
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
#  Note!
# </h1>
#
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# Since all variables in the dataset are numeric features and there are no categorical features, we do not need to apply any type of encoding such as one-hot encoding or label encoding.
# Therefore, the encoding step was skipped because the data is ready for use in classification models after performing the partitioning and standardization steps.
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# Now you need to perform feature selection, which means:
# </h1>
#
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
#  I see which columns have a significant impact on the target (stress level) and which columns are unnecessary
#
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  1-Feature Selection
#  </h1>

# %%
data.corr()
# Out:
#                               anxiety_level  self_esteem  \
# anxiety_level                      1.000000    -0.672745
# self_esteem                       -0.672745     1.000000
# mental_health_history              0.634450    -0.603502
# depression                         0.694340    -0.699602
# headache                           0.632738    -0.626058
# blood_pressure                     0.330867    -0.514692
# sleep_quality                     -0.710292     0.662693
# breathing_problem                  0.561654    -0.510514
# noise_level                        0.620639    -0.632257
# living_conditions                 -0.650543     0.637533
# safety                            -0.651220     0.643981
# basic_needs                       -0.637079     0.631212
# academic_performance              -0.649601     0.639045
# study_load                         0.551704    -0.493344
# teacher_student_relationship      -0.663176     0.652934
# ...

# %%
#cspell:disable
corr = data.corr()[['stress_level']]
plt.figure(figsize=(20,5))
sns.heatmap(corr, annot=True, cmap='seismic', linewidths=0.5, linecolor='black')
plt.show()

# %%
corr = data.corr()['stress_level'].sort_values(ascending=False)
corr
# Out:
# stress_level                    1.000000
# bullying                        0.751162
# future_career_concerns          0.742619
# anxiety_level                   0.736795
# depression                      0.734379
# headache                        0.713484
# extracurricular_activities      0.692977
# peer_pressure                   0.690684
# noise_level                     0.690435
# mental_health_history           0.648644
# breathing_problem               0.573984
# study_load                      0.561865
# blood_pressure                  0.394200
# social_support                 -0.632497
# teacher_student_relationship   -0.680163
# living_conditions              -0.698519
# basic_needs                    -0.708968
# safety                         -0.709602
# academic_performance           -0.720922
# sleep_quality                  -0.749068
# self_esteem                    -0.756195
# Name: stress_level, dtype: float64

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🔘Strong Positive Correlation:
# </h1>
#
# <h1 style="color:#A0A0A0; font-size:16px; text-align:center; font-weight:bold; text-align:left;">
#
# 1.bullying
#
# 2.future_career_concerns
#
# 3.anxiety_level
#
# 4.depression
#
# 5.headache
#
# 6.extracurricular_activities
#
# 7.peer_pressure
#
# 8.noise_level
#
# 9.mental_health_history
#
# 10.study_load
#
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🔘Moderate Positive correlation:
# </h1>
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
#    -breathing_problem
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🔘Weak Positive Correlation :
# </h1>
#
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# -blood_pressure
#
# </h1>

# %% [markdown]
#
#  <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🔘Moderate Negative Correlation:
# </h1>
#
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# -living_conditions
#
# </h1>

# %% [markdown]
#  <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🔘Strong Negative correlation:
# </h1>
#
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
# -social_support
#
# -teacher_student_relationship
#
# -basic_needs
#
# -safety
#
# -academic_performance
#
# -sleep_quality
#
# -self_esteem
#
#
# </h1>

# %%
#cspell:disable
X = data.drop('stress_level', axis=1)
Y = data['stress_level']

F_values, p_values = f_classif(X, Y)
max_length = len(max(X.columns, key=len))
for col, f, p in zip(X.columns, F_values, p_values):
    print(f"{col:<{max_length + 5}} F-value: {f:<10.3f} {'p-value: ':>15}{p:.3e}")
# Out:
# anxiety_level                     F-value: 655.453          p-value: 5.297e-188
# self_esteem                       F-value: 775.386          p-value: 1.269e-210
# mental_health_history             F-value: 398.486          p-value: 8.202e-131
# depression                        F-value: 652.629          p-value: 1.920e-187
# headache                          F-value: 570.226          p-value: 1.634e-170
# blood_pressure                    F-value: 1106.224         p-value: 9.277e-264
# sleep_quality                     F-value: 710.125          p-value: 1.397e-198
# breathing_problem                 F-value: 278.284          p-value: 1.774e-98
# noise_level                       F-value: 501.093          p-value: 2.561e-155
# living_conditions                 F-value: 522.865          p-value: 3.294e-160
# safety                            F-value: 613.635          p-value: 1.397e-179
# basic_needs                       F-value: 600.120          p-value: 8.543e-177
# ...

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
#  <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# Feature Importance in Other Models:
# </h1>
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#
# Some models can give some form of feature importance, but they are not ideal:
#
# | Model                  | Why it's not suitable for Feature Importance?  |
# |------------------------|-----------|
# | Logistic Regression    | importance” comes from the coefficients, but these values depend heavily on scaling → not reliable unless all features are standardized.   |
# | SVM                    | It does not naturally provide feature importance (except in linear SVMs, and even then it’s not very meaningful).    |
# | Decision Tree          | 	It has feature importance, but a single tree can overfit, making the importance values unstable and not generalizable.   |
# | KNN                    |It has no feature importance at all, because the algorithm is based on distances, not learned weights.    |
#
#
# ⭐ Main Advantage of Random Forest
# It reduces overfitting and gives more stable, accurate predictions.
#
# Because Random Forest builds many decision trees and combines their results, it becomes:
#
# More accurate
#
# More stable
#
# Less sensitive to noise
#
# Less likely to overfit compared to a single Decision Tree
#
# This is the number one advantage of Random Forest
# </h1>

# %%
#cspell:disable
rf = RandomForestClassifier()
rf.fit(X, Y)

fi = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf.feature_importances_
}).sort_values(by="Importance", ascending=False)

print("\n--> Feature Importance (Random Forest) ")
print(fi)
# Out:
# --> Feature Importance (Random Forest)
#                          Feature  Importance
# 5                 blood_pressure    0.171007
# 6                  sleep_quality    0.098817
# 18    extracurricular_activities    0.064053
# 16                social_support    0.063624
# 10                        safety    0.063392
# 1                    self_esteem    0.062417
# 14  teacher_student_relationship    0.059247
# 12          academic_performance    0.055346
# 0                  anxiety_level    0.052070
# 11                   basic_needs    0.051231
# 19                      bullying    0.048919
# 3                     depression    0.044238
# 4                       headache    0.040389
# 17                 peer_pressure    0.039238
# 15        future_career_concerns    0.037321
# 7              breathing_problem    0.011907
# 8                    noise_level    0.010649
# 9              living_conditions    0.010270
# 2          mental_health_history    0.008092
# ...

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
# Feature Importance (Random Forest)
# </h1>

# %%
# cspell:disable
# Add cumulative importance
fi_sorted = fi.sort_values('Importance', ascending=False).reset_index(drop=True)
fi_sorted['Cumulative'] = fi_sorted['Importance'].cumsum()

# Plot
plt.figure(figsize=(20,6))
sns.barplot(
    x="Importance",
    y="Feature",
    data=fi,
    palette=list(reversed(sns.color_palette("Reds", n_colors=len(fi)))),
    hue="Feature",
    legend=False
)
# Annotate cumulative values on bars
for i, cum in enumerate(fi_sorted['Cumulative']):
    plt.text(fi_sorted['Importance'].iloc[i] + 0.002, i, f"{cum:.2f}", va='center', fontsize=9)

plt.title('Feature Importance (Random Forest) with Cumulative Sum', fontsize=14)
plt.xlabel('Importance', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.tight_layout()
plt.show()

# Print: How many features needed to reach 80% cumulative importance
n_features_80 = (fi_sorted['Cumulative'] <= 0.80).sum()
print(f"\nFeatures needed to explain 80% importance: {n_features_80}")
print("\nTop features with cumulative importance:")
print(fi_sorted[['Feature', 'Importance', 'Cumulative']].head(n_features_80 + 1))
# Out:
# Features needed to explain 80% importance: 11
#
# Top features with cumulative importance:
#                          Feature  Importance  Cumulative
# 0                 blood_pressure    0.171007    0.171007
# 1                  sleep_quality    0.098817    0.269824
# 2     extracurricular_activities    0.064053    0.333877
# 3                 social_support    0.063624    0.397502
# 4                         safety    0.063392    0.460894
# 5                    self_esteem    0.062417    0.523311
# 6   teacher_student_relationship    0.059247    0.582558
# 7           academic_performance    0.055346    0.637904
# 8                  anxiety_level    0.052070    0.689974
# 9                    basic_needs    0.051231    0.741205
# 10                      bullying    0.048919    0.790124
# 11                    depression    0.044238    0.834363

# %% [markdown]
# ______________

# %% [markdown]
#  <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# Bivariate Analysis
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
# 1.Stress Level vs. Blood Pressure
#
#
# We perform a Bivariate Analysis between the target variable (stress_level) and one of the most significant features identified by the Random Forest model, which is blood_pressure. This helps visually confirm the correlation observed earlier
# </h1>

# %%
# cspell:disable
# Create a cross-tabulation table (Count of students per category)
cross_tab = pd.crosstab(data['stress_level'], data['blood_pressure'])

print("Cross-Tabulation (Stress Level vs. Blood Pressure):")
print(cross_tab)
# Out:
# Cross-Tabulation (Stress Level vs. Blood Pressure):
# blood_pressure  1.0  2.0  3.0
# stress_level
# 0.0               0  300   73
# 1.0             300    0   58
# 2.0               0    0  369

# %%
# cspell:disable
# Analyze the most important feature (blood_pressure) against the target
plt.figure(figsize=(20,5))
sns.countplot(data=data, x='stress_level', hue='blood_pressure', palette='Reds')
plt.title('Stress Level Distribution by Blood Pressure', fontsize=14)
plt.xlabel("Stress Level")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# #### 📝 Key Insights
#
# **High Stress Indicator:**
# Students with **High Blood Pressure (3.0)** constitute **100%** of the **High Stress (2.0)** category, making High BP an almost perfect physiological marker for the highest stress level.
#
# **Segmentation by BP:**
# Blood Pressure perfectly segments the lower stress groups:
# - **Normal BP (2.0)** → exclusively in **Low Stress (0.0)** students
# - **Low BP (1.0)** → exclusively in **Medium Stress (1.0)** students
#
# **Predictive Power:**
# The `blood_pressure` feature demonstrates an **exceptional level of predictive power**, acting as a crucial, definitive factor in classifying students into specific stress categories.

# %% [markdown]
# ______________

# %% [markdown]
# #### 2. Preventive Factors vs Stress Levels
#
# **Objective:**
# To analyze how **self_esteem** and **sleep_quality** vary across stress levels and identify key patterns.
#
#
# **Suggested Plot:**
# We use **Box Plots** to clearly show the **range and median** of `self_esteem` and `sleep_quality` across different stress levels.

# %%
# cspell:disable
# Group by stress_level and calculate descriptive statistics
summary = data.groupby('stress_level')[['self_esteem', 'sleep_quality']].agg(['mean','median','std','min','max'])

# Display with nice formatting
summary.style.background_gradient(cmap='coolwarm').format("{:.2f}")
# Out:
# <style type="text/css">
# #T_ddb4d_row0_col0, #T_ddb4d_row0_col1, #T_ddb4d_row0_col2, #T_ddb4d_row0_col5, #T_ddb4d_row0_col6, #T_ddb4d_row0_col7, #T_ddb4d_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ddb4d_row0_col3, #T_ddb4d_row0_col4, #T_ddb4d_row0_col8, #T_ddb4d_row0_col9, #T_ddb4d_row1_col2, #T_ddb4d_row1_col4, #T_ddb4d_row1_col7, #T_ddb4d_row1_col8, #T_ddb4d_row1_col9, #T_ddb4d_row2_col0, #T_ddb4d_row2_col1, #T_ddb4d_row2_col3, #T_ddb4d_row2_col4, #T_ddb4d_row2_col5, #T_ddb4d_row2_col6, #T_ddb4d_row2_col8, #T_ddb4d_row2_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ddb4d_row1_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ddb4d_row1_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_ddb4d_row1_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_ddb4d_row1_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_ddb4d_row2_col2 {
#   background-color: #d44e41;
# ...

# %%
#cspell:disable
variables = ['self_esteem', 'sleep_quality']
plt.figure(figsize=(14,6))

colors = ["#8e0202a9","#B50303","#5e0101"]  # Custom colors for stress levels

for i, var in enumerate(variables, 1):
    plt.subplot(1, 2, i)
    sns.boxplot(x='stress_level', y=var, data=data, palette=colors, hue='stress_level', dodge=False )
    plt.legend(loc='upper right')  
    plt.title(f'{var.replace("_", " ").title()} by Stress Level', fontsize=14)
    plt.xlabel('Stress Level (0: Low, 1: Medium, 2: High)', fontsize=12)
    plt.ylabel(var.replace("_", " ").title(), fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📝 Key Insights
#
# - **Self Esteem & Sleep Quality decrease as Stress increases**.
# - **Low Stress:** High self_esteem (25.25) & good sleep_quality (4.13)
# - **Medium Stress:** Moderate self_esteem (19.26) & sleep_quality (2.53)
# - **High Stress:** Low self_esteem (8.78) & poor sleep_quality (1.30)
#
# **Conclusion:** Preventive factors strongly reduce stress; interventions should focus on improving self-esteem and sleep quality.

# %% [markdown]
# ______________________________________

# %% [markdown]
# #### **3. Multivariate Analysis: Anxiety vs Social Support**
#
# **Objective:**
# To understand how **social support** influences stress levels at different levels of **anxiety**, using both **numeric summary** and **visual heatmap**.

# %%
#cspell:disable
#  Pivot table: mean stress level
stress_pivot = data.pivot_table(
    values='stress_level',
    index='social_support',
    columns='anxiety_level',
    aggfunc='mean'
)

# Custom colormap: light burgundy -> dark red
colors = ["#FDE0DC", "#F28E8E", "#21020B"]  # فاتح -> متوسط -> غامق
cmap = LinearSegmentedColormap.from_list("RedBurgundy", colors)

# Display numeric summary with color gradient
display(stress_pivot.style.background_gradient(cmap=cmap).format("{:.2f}"))

# Visual Heatmap
plt.figure(figsize=(20,5))
sns.heatmap(
    stress_pivot,
    annot=True,
    fmt=".2f",
    cmap=cmap,
    linecolor='gray',
    linewidths=0.5,
    cbar_kws={'label': 'Mean Stress Level'},
    annot_kws={"size": 8}
)
plt.title('Mean Stress Level by Social Support and Anxiety Level', fontsize=10, fontweight='bold')
plt.ylabel('Social Support Score', fontsize=12)
plt.xlabel('Anxiety Level Score', fontsize=12)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# #T_05f75_row0_col0, #T_05f75_row0_col1, #T_05f75_row0_col6, #T_05f75_row0_col7, #T_05f75_row0_col8, #T_05f75_row0_col9, #T_05f75_row0_col11, #T_05f75_row0_col12, #T_05f75_row1_col0, #T_05f75_row1_col2, #T_05f75_row1_col3, #T_05f75_row1_col4, #T_05f75_row1_col5, #T_05f75_row1_col10, #T_05f75_row1_col13, #T_05f75_row1_col14, #T_05f75_row1_col15, #T_05f75_row1_col16, #T_05f75_row1_col17, #T_05f75_row1_col18, #T_05f75_row1_col19, #T_05f75_row1_col20, #T_05f75_row1_col21, #T_05f75_row2_col12, #T_05f75_row2_col13, #T_05f75_row3_col12, #T_05f75_row3_col13 {
#   background-color: #21020b;
#   color: #f1f1f1;
# }
# #T_05f75_row0_col2 {
#   background-color: #f7b2b0;
#   color: #000000;
# }
# #T_05f75_row0_col3 {
#   background-color: #6c353a;
#   color: #f1f1f1;
# }
# #T_05f75_row0_col4 {
#   background-color: #4f2128;
#   color: #f1f1f1;
# }
# #T_05f75_row0_col5 {
#   background-color: #ac5f62;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# #### **📝 Key Insights: Anxiety vs Social Support**
#
# - **High stress** occurs when **anxiety is high** and **social support is low**.
# - **Low stress** occurs when **social support is high**, even at moderate anxiety.
# - **Trend:** Stress rises as anxiety increases and support decreases; stress drops as support increases.
# - **Note on NaN:** Some cells show `NaN` because no students exist for that combination—this is normal and not a data issue.
# - **Conclusion:** Social support buffers anxiety, reducing stress levels.

# %% [markdown]
# _____________________

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
#
# All variables have a statistically significant effect on stress levels, with psychological, environmental, and academic factors having the strongest influence. Improving social support, sleep, and environment reduces stress.
#
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 2-Handling Imbalanced Data:
# </h1>

# %%
# cspell:disable
colors = [  '#701705',"#9C2108","#DB2804"]

counts = Y.value_counts()
labels = counts.index  

plt.figure(figsize=(5,5))
plt.pie(
    counts,
    labels=labels,
    autopct='%1.1f%%',
    colors=colors,
    startangle=140,
    textprops={'fontsize': 12},
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Stress Level Distribution', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:20px; text-align:center; font-weight:bold; text-align:left;">
#
# Since the dataset is balanced, accuracy can be used as a reliable metric for model evaluation, and no resampling techniques (such as SMOTE or undersampling) are required.
#
#
# </h1>

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 3-Train-test split:
# </h1>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 4- Data Scaling:
# </h1>

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)
print(f"X_train shape: {X_train_scaled.shape}")
print(f"X_test shape: {X_test_scaled.shape}")
# Out:
# X_train shape: (880, 20)
# X_test shape: (220, 20)

# %% [markdown]
# **After scaling the data, we apply PCA to visualize the distribution in two dimensions.**

# %%
# cspell:disable
X_pca = PCA(n_components=2, random_state=42).fit_transform(X_train_scaled)

reds = plt.cm.Reds
truncated_reds = mcolors.LinearSegmentedColormap.from_list(
    "truncatedReds", reds(np.linspace(0.3, 1, 256))
)

# رسم
plt.figure(figsize=(20,5))
plt.scatter(X_pca[:,0], X_pca[:,1], c=y_train, cmap=truncated_reds, s=20)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('PCA 2D Projection (Stress Level)')
plt.colorbar(ticks=[0,1,2], label='Stress Level')
plt.grid(alpha=0.2)
plt.show()

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# <span style="color:#800000;">3-</span> Algorithms (Classification Models)
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  🔘Import Required Libraries
#
# </h1>

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 1-Logistic Regression
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Note:
#
#  Logistic Regression is a simple linear model used as a first baseline.
#
#
#  It works well when features have linear relationships with the target.
#
# </h1>

# %%
accuracy_scores = {}

# %%
log_reg = LogisticRegression(max_iter = 2000)
log_reg.fit(X_train_scaled, y_train)
y_pred_lr = log_reg.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred_lr)
accuracy_scores['logistic regression'] = accuracy

report_dict = classification_report(y_test, y_pred_lr, output_dict=True)
df_report = pd.DataFrame(report_dict).drop(['accuracy'], axis=1).transpose()

cm = confusion_matrix(y_test, y_pred_lr)
df_cm = pd.DataFrame(cm, index=[f"Actual_{cls}" for cls in log_reg.classes_],
                     columns=[f"Pred_{cls}" for cls in log_reg.classes_])

print(f"Logistic Regression Accuracy: {accuracy:.3f}")
print("\n✅ Classification Report:\n")
print(df_report)
print("\n✅ Confusion Matrix:\n")
print(df_cm)
# Out:
# Logistic Regression Accuracy: 0.886
#
# ✅ Classification Report:
#
#               precision    recall  f1-score  support
# 0.0            0.894737  0.894737  0.894737     76.0
# 1.0            0.878378  0.890411  0.884354     73.0
# 2.0            0.885714  0.873239  0.879433     71.0
# macro avg      0.886277  0.886129  0.886174    220.0
# weighted avg   0.886397  0.886364  0.886352    220.0
#
# ✅ Confusion Matrix:
#
#             Pred_0.0  Pred_1.0  Pred_2.0
# Actual_0.0        68         4         4
# Actual_1.0         4        65         4
# Actual_2.0         4         5        62

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 2-Support Vector Machine (SVM)
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#  Note:
#
# SVM is powerful for classification especially for non-linear boundaries.
#
# Works best when the data is scaled (which we already did).
#
#
# </h1>

# %%
svm_clf = SVC(kernel='rbf')
svm_clf.fit(X_train_scaled, y_train)
y_pred_svm = svm_clf.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test, y_pred_svm)
accuracy_scores['SVM'] = accuracy

report_dict = classification_report(y_test, y_pred_svm, output_dict=True)
df_report = pd.DataFrame(report_dict).drop(['accuracy'], axis=1).transpose()

cm = confusion_matrix(y_test, y_pred_svm)
df_cm = pd.DataFrame(cm, index=[f"Actual_{cls}" for cls in svm_clf.classes_],
                     columns=[f"Pred_{cls}" for cls in svm_clf.classes_])

print(f"SVM Accuracy: {accuracy:.3f}")
print("\n✅ Classification Report + Accuracy:\n")
print(df_report)
print("\n✅ Confusion Matrix:\n")
print(df_cm)
# Out:
# SVM Accuracy: 0.882
#
# ✅ Classification Report + Accuracy:
#
#               precision    recall  f1-score  support
# 0.0            0.800000  0.947368  0.867470     76.0
# 1.0            0.953846  0.849315  0.898551     73.0
# 2.0            0.923077  0.845070  0.882353     71.0
# macro avg      0.892308  0.880585  0.882791    220.0
# weighted avg   0.890769  0.881818  0.882586    220.0
#
# ✅ Confusion Matrix:
#
#             Pred_0.0  Pred_1.0  Pred_2.0
# Actual_0.0        72         1         3
# Actual_1.0         9        62         2
# Actual_2.0         9         2        60

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 3-Decision Tree
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Note:
#
#
# Decision Tree is a simple and interpretable model.
#
# It splits the data into branches based on the most informative features.
#
# Useful for understanding feature importance and model explainability.
#
#
#
# </h1>

# %%
#cspell:disable
dt_model = DecisionTreeClassifier(
    criterion='gini',         
    max_depth=None,           
    random_state=42
)

dt_model.fit(X_train, y_train)
y_pred_dt = dt_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_dt)
accuracy_scores['Decision Tree'] = accuracy

performance_dict = classification_report(y_test, y_pred_dt, output_dict=True)
performance_report = pd.DataFrame(performance_dict).drop(['accuracy'], axis=1).T

cm = confusion_matrix(y_test, y_pred_dt)
df_cm = pd.DataFrame(cm, index=[f'Actual_{c}' for c in dt_model.classes_], columns=[f'Pred_{c}' for c in dt_model.classes_])

print(f"🌳 Decision Tree Accuracy: {accuracy:.3f}")
print("\n✅Classification Report:\n")
print(performance_report)
print("\n✅Confusion Matrix:\n")
print(df_cm)
# Out:
# 🌳 Decision Tree Accuracy: 0.891
#
# ✅Classification Report:
#
#               precision    recall  f1-score  support
# 0.0            0.884615  0.907895  0.896104     76.0
# 1.0            0.868421  0.904110  0.885906     73.0
# 2.0            0.924242  0.859155  0.890511     71.0
# macro avg      0.892426  0.890386  0.890840    220.0
# weighted avg   0.892031  0.890909  0.890915    220.0
#
# ✅Confusion Matrix:
#
#             Pred_0.0  Pred_1.0  Pred_2.0
# Actual_0.0        69         4         3
# Actual_1.0         5        66         2
# Actual_2.0         4         6        61

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 4-Random Forest
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Note:
#
#  Random Forest is a very strong non-linear model.
#
#  It handles noisy data well and captures complex interactions between features.
#
#
# </h1>

# %%
rf_model = RandomForestClassifier(n_estimators=300, random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_rf)
accuracy_scores['Random Forest'] = accuracy

performance_dict = classification_report(y_test, y_pred_rf, output_dict=True)
performance_report = pd.DataFrame(performance_dict).drop(['accuracy'], axis=1).T

cm = confusion_matrix(y_test, y_pred_rf)
df_cm = pd.DataFrame(cm, index=[f'Actual_{c}' for c in rf_model.classes_], columns=[f'Pred_{c}' for c in rf_model.classes_])

print(f"🌳🌳🌳 Random Forest Accuracy: {accuracy:.3f}")
print("\n✅Classification Report:\n")
print(performance_report)
print("\n✅Confusion Matrix:\n")
print(df_cm)
# Out:
# 🌳🌳🌳 Random Forest Accuracy: 0.877
#
# ✅Classification Report:
#
#               precision    recall  f1-score  support
# 0.0            0.837500  0.881579  0.858974     76.0
# 1.0            0.941176  0.876712  0.907801     73.0
# 2.0            0.861111  0.873239  0.867133     71.0
# macro avg      0.879929  0.877177  0.877970    220.0
# weighted avg   0.879522  0.877273  0.877809    220.0
#
# ✅Confusion Matrix:
#
#             Pred_0.0  Pred_1.0  Pred_2.0
# Actual_0.0        67         3         6
# Actual_1.0         5        64         4
# Actual_2.0         8         1        62

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 5-KNN Classifier
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Note:
#
# KNN predicts based on the closest neighbors.
#
# It must be trained on scaled data to avoid bias from large-number features.
#
#
#
# </h1>

# %%
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(X_train_scaled, y_train)
y_pred_knn = knn.predict(X_test_scaled)

# %%
#cspell:disable
accuracy = accuracy_score(y_test, y_pred_knn)
accuracy_scores['KNN'] = accuracy

peknnormance_dict = classification_report(y_test, y_pred_knn, output_dict=True)
peknnormance_report = pd.DataFrame(peknnormance_dict).drop(['accuracy'], axis=1).T

cm = confusion_matrix(y_test, y_pred_knn)
df_cm = pd.DataFrame(cm, index=[f'Actual_{c}' for c in knn.classes_], columns=[f'Pred_{c}' for c in knn.classes_])

print(f"KNN Accuracy: {accuracy:.3f}")
print("\n✅Classification Report:\n")
print(peknnormance_report)
print("\n✅Confusion Matrix:\n")
print(df_cm)
# Out:
# KNN Accuracy: 0.900
#
# ✅Classification Report:
#
#               precision    recall  f1-score  support
# 0.0            0.943662  0.881579  0.911565     76.0
# 1.0            0.841463  0.945205  0.890323     73.0
# 2.0            0.925373  0.873239  0.898551     71.0
# macro avg      0.903500  0.900008  0.900146    220.0
# weighted avg   0.903848  0.900000  0.900316    220.0
#
# ✅Confusion Matrix:
#
#             Pred_0.0  Pred_1.0  Pred_2.0
# Actual_0.0        67         7         2
# Actual_1.0         1        69         3
# Actual_2.0         3         6        62

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🔘Compare All Models
# </h1>

# %% [markdown]
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
# Note:
#
#
# This table helps you choose the best model based on accuracy.
#
# | Model                  | Accuracy  |
# |------------------------|-----------|
# | Logistic Regression    | 0.8864    |
# | SVM                    | 0.8818    |
# | Decision Tree          | 0.8909    |
# | Random Forest          | 0.8773    |
# | KNN                    | 0.9000    |
#
#
#
# </h1>

# %%
# cspell:disable
#  Model accuracy results
results = {
    'Logistic Regression': 0.886,
    'SVM': 0.882,
    'Decision Tree': 0.891,
    'Random Forest': 0.877,
    'KNN': 0.9
}

# Soft red gradient from dark red to light pink
colors = ['#800020', '#a8323e', '#c0515c', '#e07280', '#f5a5aa']  # dark → light red

# Find the best model
best_model = max(results, key=results.get)

# Highlight the best model with a brighter red
highlight_colors = [c if model != best_model else "#c70a0a" for c, model in zip(colors, results.keys())]

plt.figure(figsize=(20,6))
bars = plt.bar(results.keys(), results.values(), color=highlight_colors,width=0.5)
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.ylim(0.85, 0.92)

# Annotation for the best model
for bar, model in zip(bars, results.keys()):
    if model == best_model:
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.002,
                "Best", ha='center', color='red', fontweight='bold')

plt.show()

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# 🏆Best Model Selection
# </h1>
#
#
#
# <h1 style="color:#A0A0A0; font-size:18px; text-align:center; font-weight:bold; text-align:left;">
#
#
# | Model                  | Accuracy  |
# |------------------------|-----------|
# | KNN                    | 0.9000    |
#
#
#  Note:
#
#   Automatically selects the highest accuracy model.
#
#
# </h1>

# %%
print( pd.DataFrame(accuracy_scores.items(), columns=[f"{'Model':<19}" , "Accuracy"]))
best_model = max(accuracy_scores, key=accuracy_scores.get)
best_accuracy = accuracy_scores[best_model]

print("\n🏆 Best Model is:", best_model)
print("🏆 Accuracy:", best_accuracy)
# Out:
#    Model                Accuracy
# 0  logistic regression  0.886364
# 1                  SVM  0.881818
# 2        Decision Tree  0.890909
# 3        Random Forest  0.877273
# 4                  KNN  0.900000
#
# 🏆 Best Model is: KNN
# 🏆 Accuracy: 0.9

# %%
#cspell:disable
colors = ('#440E03', '#C82909', '#F87C63')
cmap = LinearSegmentedColormap.from_list("RedBurgundy", colors)

# Plot Confusion Matrix
plt.figure(figsize=(20, 5))
sns.heatmap(df_cm, annot=True, fmt='d', cmap=cmap, cbar=False)
plt.title('Confusion Matrix (KNN)', fontsize=14)
plt.xlabel('Predicted Label', fontsize=12)
plt.ylabel('True Label', fontsize=12)
plt.show()

# %% [markdown]
# #### 📝 KNN Model Insights (Summary)
#
# - **Accuracy:** 0.900 → Very reliable overall.
# - **Low Stress (0.0):** Predicted very well; minor confusion with Medium Stress.
# - **Medium Stress (1.0):** Slight underestimation; some misclassified as Low or High.
# - **High Stress (2.0):** Strong performance; few misclassifications with Medium Stress.
# - **Pattern:** Most errors occur **between adjacent stress levels**.
# - **Conclusion:** KNN is effective, especially for extreme stress levels; medium stress is the trickiest to classify.

# %% [markdown]
# <hr style="border: 1px solid #800000;">

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:left;">
# <span style="color:#800000;">4-</span>  Insights & Recommendations
# </h1>

# %% [markdown]
# <hr style="border: 1px solid #800000;">
#
# ## **A. Insights**
#
# ### **1. Key Stress Drivers (Top 5 Features)**
# Based on **Random Forest Feature Importance**, the main factors increasing student stress are:
# - 🔴 **blood_pressure** → High physiological stress marker
# - 🔴 **sleep_quality** → Poor sleep significantly increases stress
# - 🔴 **safety** → Unsafe environments elevate stress levels
# - 🔴 **extracurricular_activities** → Overload or lack of structured activities impacts stress
# - 🔴 **depression** → Strong psychological driver of high stress
#
# ---
#
# ### **2. Protective Factors**
# Factors negatively correlated with stress (higher values → lower stress):
# - 🔴 **self_esteem** → Boosts resilience against stress
# - 🔴 **sleep_quality** → Better sleep reduces stress
# - 🔴 **academic_performance** → High performance linked to lower stress
# - 🔴 **social_support** → Support networks mitigate stress
#
# *Insight:* Enhancing these protective factors can effectively reduce overall stress levels among students.
#
# ---
#
# ### **3. Model Performance**
# - 🔴 **Best Model:** KNN
# - 🔴 **Accuracy:** 0.90
# - 🔴 *Scaling features was essential due to KNN’s distance-based calculation*
# - **Confusion Matrix Analysis:**
#   - Most misclassifications occur **between adjacent stress levels (0 ↔ 1, 1 ↔ 2)**
#   - Low and High Stress levels are predicted most accurately, Medium Stress slightly less
#
# ---
#
# ### **4. Data Overview**
# - 🔴 **Balanced dataset** → Accuracy is reliable
# - 🔴 Exploratory Data Analysis confirms **no extreme outliers** and **consistent distributions**
#
# <hr style="border: 1px solid #800000;">
#
# ## **B. Recommendations**
#
# ### **1. Psychological & Social Support**
# - Focus on **depression, self-esteem, social support**
# - Actions:
#   - Peer mentoring programs
#   - Counseling sessions
#   - Mental health workshops
#
# ### **2. Safe & Comfortable Environment**
# - Address **safety** and **living_conditions**
# - Actions:
#   - Secure campus and dormitories
#   - Comfortable, ergonomic study areas
#   - Clear safety protocols
#
# ### **3. Time & Activity Management**
# - Manage **extracurricular_activities** to avoid stress overload
# - Actions:
#   - Structured guidance for balancing academics and activities
#   - Programs to prevent excessive workload or inactivity
#
# ### **4. Physical Health & Sleep Hygiene**
# - Focus on **sleep_quality** and **blood_pressure monitoring**
# - Actions:
#   - Sleep awareness campaigns
#   - Health screenings and fitness initiatives
#   - Encourage regular check-ups
#
# <hr style="border: 1px solid #800000;">
#
# ## **C. Summary**
# > By integrating **feature importance, multivariate analysis, and KNN model performance**, we can clearly identify **risk factors and protective factors** for student stress.
# > Implementing **targeted psychological, social, environmental, and physical health interventions** will maximize student wellbeing and enable **data-driven decision-making**.

# %% [markdown]
# __________

# %% [markdown]
# <h1 style="color:#D3D3D3; font-size:20px; font-weight:bold; text-align:center;">
# Ha Ya Handasa - We did it ولا we dead?
# </h1>

# %% [markdown]
# <div style="text-align:center;">
#     <img src="photo_2025-12-11_21-47-47.jpg"width="550">
# </div>
